# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
vgg19 = load_model("fakelogo.h5")

# %%
import numpy as np

# %%
def resize_image(image, size=(256, 256)):
    return tensorflow.image.resize(image, size)

# %%
# testing 1

img = image.load_img('/workspaces/SI-GuidedProject-592631-1697551698/Project Development Phase/genLogoOutput/Adidas/000001.jpg',target_size =(224,224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x,axis = 0)
pred =np.argmax(vgg19.predict(x))
op = ['Adidas', 'Amazon', 'Ariel', 'Apple', 'BMW', 'Bic', 'Burger King', 'Cadbury', 'Chevrolet', 'Chrome', 'Coca Cola', 'Cowbell', 'Dominos', 'Fila', 'Goya oil', 'Guinness', 'Heinz', 'Honda', 'Huawei', 'Hp', 'Instagram', 'Kfc', 'Krisspy Kreme', 'Lays', 'Levis', 'Lg', 'Lipton', 'Mars', 'Marvel', 'McDonald', 'Mercedes Benz', 'Microsoft', 'MnM', 'Mtn', 'Mtn dew', 'NASA', 'Nestle', 'Nestle milo', 'Nescafe', 'Nike', 'Nutella', 'Oreo', 'Oral b', 'Pepsi', 'PlayStation', 'Pringles', 'Puma', 'Rolex', 'Samsung', 'Sprite', 'Starbucks', 'Tiktok', 'Tesla', 'Twitter', 'YouTube', 'Zara']
op[pred]
# Out:
# 1/1 [==============================] - 0s 456ms/step
# 'Adidas'
